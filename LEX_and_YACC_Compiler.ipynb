# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishali28h-crypto/IBM/blob/main/LEX_and_YACC_Compiler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %{
    #include<stdio.h>
    %}

    %%
    bool|int|float printf("keyword");
    [-,+]?[0,9]+ printf("constants");
    [,""]+ printf("punctuation chars");
    [!@]+ printf("special chars");
    [a-zA-Z]+ printf("Identifiers");

     %%

     int yywrap()
     {return 1;
     }
     main()
     {
         yylex();
     }

     gcc lex.yy.c
    ./a.out
# Out:
#   File "/tmp/ipython-input-2884787311.py", line 3
#     get_ipython().run_line_magic('}', '')
#     ^
# IndentationError: unexpected indent
